# %%
import pandas as pd


df_bourso = pd.read_csv("./boursorama.csv")
df_bourso
# Out:
#          cours                 date                        name  valeur_basse  \
# 0    1 103.499  2022-10-26 15:57:30                        ATOS         9.348
# 1    2 431.290  2022-10-26 15:57:30                    OVHCLOUD        12.100
# 2    1 917.959  2022-10-26 15:57:30                      ERAMET        62.750
# 3      348.820  2022-10-26 15:57:30                MCPHY ENERGY        11.915
# 4    4 319.634  2022-10-26 15:57:30  GTT (GAZTRANSPORT ET TEC.)       111.800
# ..         ...                  ...                         ...           ...
# 59   1 763.821  2022-10-26 15:57:30                     EUROAPI        18.540
# 60  12 595.640  2022-10-26 15:57:30         EUROFINS SCIENTIFIC        64.020
# 61  12 524.326  2022-10-26 15:57:30                     EDENRED        49.760
# 62     914.031  2022-10-26 15:57:30   CASINO GUICHARD PERRACHON         8.305
# 63  25 150.867  2022-10-26 15:57:30                      ORANGE         9.378
#
# ...
